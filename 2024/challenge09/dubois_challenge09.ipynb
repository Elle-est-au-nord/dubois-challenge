# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#    Year  Slave   Free
# 0  1790   92.0    8.0
# 1  1800   89.0   11.0
# 2  1810   86.5   13.5
# 3  1820   87.0   13.0
# 4  1830   86.0   14.0
# 5  1840   87.0   13.0
# 6  1850   88.0   12.0
# 7  1860   89.0   11.0
# 8  1870    0.0  100.0

# %%
df.plot.area(x="Year", legend=False, color=['#212529', '#39a875'], figsize=(10,10))
# Out:
# <Axes: xlabel='Year'>
