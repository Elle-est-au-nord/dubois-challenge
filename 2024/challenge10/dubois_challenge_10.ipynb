# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#            Occupation  Percentage
# 0            Teachers        58.5
# 1           Ministers         4.3
# 2  Government Service         3.2
# 3            Business         2.1
# 4   Other Professions         3.8
# 5         House Wives        28.1

# %%
plot = df.plot.pie(y='Percentage', figsize=(10, 10), legend=False, xlabel='', ylabel='', labels=None,
                   colors=["#f2335f", "#5e81ac", "#cabb97", "#f3e0e0", "#62867d", "#fdca41"])
