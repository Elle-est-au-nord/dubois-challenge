# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#   Category  Percentage
# 0    Black          44
# 1    Brown          40
# 2   Yellow          16

# %%
data = pd.DataFrame({'Black': 44, 'Brown': 40, 'Yellow': 16}, index=['Foo'])

# %%
data.plot.bar(stacked=True, legend=False, figsize=(7,12),
              color={'Black': '#1b1b1b', 'Brown': '#552b27', 'Yellow': '#fdca41'})
# Out:
# <Axes: >
