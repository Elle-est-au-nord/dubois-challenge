# %%
# From docs: https://matplotlib.org/stable/users/explain/colors/colormaps.html

# %%
from matplotlib import colormaps
from colorspacious import cspace_converter

import matplotlib.pyplot as plt
import numpy as np

import matplotlib as mpl#

# %%
cmaps = {}

gradient = np.linspace(0, 1, 256)
gradient = np.vstack((gradient, gradient))


def plot_color_gradients(category, cmap_list):
    # Create figure and adjust figure height to number of colormaps
    nrows = len(cmap_list)
    figh = 0.35 + 0.15 + (nrows + (nrows - 1) * 0.1) * 0.22
    fig, axs = plt.subplots(nrows=nrows + 1, figsize=(6.4, figh))
    fig.subplots_adjust(top=1 - 0.35 / figh, bottom=0.15 / figh,
                        left=0.2, right=0.99)
    axs[0].set_title(f'{category} colormaps', fontsize=14)

    for ax, name in zip(axs, cmap_list):
        ax.imshow(gradient, aspect='auto', cmap=mpl.colormaps[name])
        ax.text(-0.01, 0.5, name, va='center', ha='right', fontsize=10,
                transform=ax.transAxes)

    # Turn off *all* ticks & spines, not just the ones with colormaps.
    for ax in axs:
        ax.set_axis_off()

    # Save colormap list for later.
    cmaps[category] = cmap_list

# %%
plot_color_gradients('Perceptually Uniform Sequential',
                     ['viridis', 'plasma', 'inferno', 'magma', 'cividis'])

# %%
fig, ax = plt.subplots(figsize=(10,2))
ax.imshow(gradient, aspect='auto', cmap=mpl.colormaps['viridis'])

# %%
from matplotlib.colors import ListedColormap

# %%
gradient1 = [[(241, 222, 192), (241, 218, 181), (242, 218, 159)]]
gradient1 = np.vstack((gradient1, gradient1))

# %%
fig, ax = plt.subplots(figsize=(10,2))
ax.imshow(gradient1, aspect='auto')

# %%
fig, ax = plt.subplots(figsize=(10,2))
ax.imshow([[(243, 207, 126), (180, 152, 89), (155, 124, 89)]], aspect='auto')

# %%
fig, ax = plt.subplots(figsize=(10,2))
ax.imshow([[(134, 108, 77), (92, 72, 53), (63, 49, 36)]], aspect='auto')

# %%
fig, ax = plt.subplots(figsize=(10,10))
full_gradient_colors = [[(241, 222, 192), (241, 218, 181), (242, 218, 159), (243, 207, 126), (180, 152, 89), (155, 124, 89), (134, 108, 77), (92, 72, 53), (63, 49, 36)]] 
ax.imshow(full_gradient_colors, interpolation='bicubic', aspect='auto')

# %%
fig, ax = plt.subplots(figsize=(10,2))
ax.imshow([[(243, 207, 126), (180, 152, 89), (155, 124, 89)]], interpolation='bicubic', aspect='auto')

# %%
fig, ax = plt.subplots(figsize=(10,2))
ax.imshow([[(155, 124, 89)], [(180, 152, 89)], [(243, 207, 126)]], interpolation='bicubic', aspect='auto')

# %%
wh1, wh2 = [(250, 240, 227)], [(247, 233, 213)]
be1, be2, be3 = [(241, 222, 192)], [(241, 218, 181)], [(242, 218, 159)] # Beiges
br1, br2, br3 = [(243, 207, 126)], [(180, 152, 89)], [(155, 124, 89)] # Browns
bl1, bl2, bl3 = [(134, 108, 77)], [(92, 72, 53)], [(63, 49, 36)]  # Blacks
bl4, bl5, bl6 = [(44, 33, 22)], [(24, 17, 10)], [(15, 16, 18)]
color_gradient = [[(0,0,0)], bl6, bl5, bl5, bl4, bl3, bl2, bl1, br3, be2, be1, wh2, wh1]

# %%
fig, ax = plt.subplots(figsize=(10,10))
extent = 1800, 1890, 0, 11757489
ax.imshow(color_gradient, interpolation='bicubic', aspect='auto', alpha=.7, extent=extent)
