# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data.csv")

# %%
data
# Out:
#    Year   Slave     Free
# 0  1860      89       11
# 1  Year  Owners  Tenants
# 2  1890      19       81

# %%
df1 = pd.DataFrame({'slave': [89],
                   'free': [11]}, index=[1860])

# %%
df2 = pd.DataFrame({'tenants': [81],
                   'owners': [19]}, index=[1890])

# %%
df1.plot.bar(stacked=True, legend=False, color=['#212529', '#39a875'], figsize=(7,6))
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True, legend=False, color=['#39a875', '#ff004c'], figsize=(7,8))
# Out:
# <Axes: >
