# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data.csv")

# %%
data
# Out:
#             nation  illiteracy
# 0         Roumanie   72.936300
# 1           Servie   72.290800
# 2           Russie   72.290800
# 3  Negroes, U.S.A.   56.800000
# 4          Hongrie   55.509000
# 5           Italie   43.890900
# 6         Autriche   34.854500
# 7          Ireland   25.172700
# 8           France   12.909100
# 9            Suede    0.645454

# %%
mpl.style.use('seaborn-v0_8-pastel')

data.plot(kind='barh', y='illiteracy', x='nation', color='#39a875', 
          legend=False, ylabel='', xticks=[], figsize=(8,12), width=.5)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(8,12))
barplot = plt.barh(data.nation, data.illiteracy, .5, color='#39a875')
barplot[3].set_color('#ff004c')
